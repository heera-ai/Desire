# %% [markdown]
# # Assignment : 1

# %%
#from IPython.display import Image
#Image(filename='Screenshot (1).png')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
object_weight = np.arange(10,1000,10)
#print(object_weight)

# %%
F_m = 75 + 8.4 * object_weight
#print(F_m)

# %%
plt.plot(object_weight,F_m)
plt.grid(True)
plt.title ('Muscle force wrt to object weight')
plt.xlabel('object_weight')
plt.ylabel("Muscle Force")
slope, intercept, r_value, p_value, std_err = linregress([object_weight[10],object_weight[0]],[F_m[10],F_m[0]])
print('slope = ' + str(slope),'\nintercept = ' + str(intercept))
# Out:
# slope = 8.4
# intercept = 75.0

# %%
F_j = 755 - object_weight
#print(F_j)

# %%
plt.plot(object_weight,F_j)
plt.plot(object_weight,F_m)
plt.title ('Joint force wrt object weight')
plt.xlabel('object_weight')
plt.ylabel("Joint Force")
plt.grid(True)
slope, intercept, r_value, p_value, std_err = linregress([object_weight[10],object_weight[0]],[F_j[10],F_j[0]])
print('slope = ' + str(slope),'\nintercept = ' + str(intercept))
# Out:
# slope = -1.0
# intercept = 755.0

# %%
plt.plot(F_j,F_m)
plt.title ('Joint force wrt Muscle Force')
plt.xlabel('Joint force')
plt.ylabel("Muscle Force")
plt.grid(True)
slope, intercept, r_value, p_value, std_err = linregress([F_j[10],F_j[0]],[F_m[10],F_m[0]])
print('slope = ' + str(slope),'\nintercept = ' + str(intercept))
# Out:
# slope = -8.4
# intercept = 6417.0
